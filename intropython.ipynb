# %%
happy=14
print(happy)
# Out:
# 14

# %%
sad=17
happy=91
print(happy+sad)
# Out:
# 108

# %%
total=sad+happy
print(total)
# Out:
# 108

# %% [markdown]
# # GDP per capita

# %%
import pandas as pd

GDPcap = pd.read_excel (r'BCLDatabase_online_v2.4.xlsx', 
                    sheet_name="GDP per capita")
print (GDPcap)
# Out:
#      Year           AUS           AUT           BEL           CAN  \
# 0    1890   8773.621382   4831.877350   4593.012106   4520.862868
# 1    1891   9184.546914   4966.374691   4531.899209   4578.550947
# 2    1892   7863.803255   5044.792029   4577.673020   4506.534723
# 3    1893   7297.826136   5037.894633   4578.748374   4435.938377
# 4    1894   7411.350492   5283.105231   4579.134233   4600.855868
# ..    ...           ...           ...           ...           ...
# 125  2015  48508.512900  48980.412430  42816.558182  46778.741303
# 126  2016  48887.422466  49462.692531  43230.086097  46715.194906
# 127  2017  49484.241049  50336.741242  43883.747532  47624.230723
# 128  2018  49654.242225  51304.273698  44334.315101  47908.771527
# 129  2019  49782.269777  51917.172343  44733.827198  48013.528771
#
#               CHE           CHL           DEU           DNK           ESP  \
# 0     8291.383494   2124.391866   5917.076199   4596.498656   4037.580800
# ...

# %%
import pandas as pd

GDPcap = pd.read_csv (r'BCL_GDP.csv')
print (GDPcap)
# Out:
#      Year     AUS     AUT     BEL     CAN     CHE     CHL     DEU     DNK  \
# 0    1890   8,774   4,832   4,593   4,521   8,291   2,124   5,917   4,596
# 1    1891   9,185   4,966   4,532   4,579   7,784   2,269   5,886   4,655
# 2    1892   7,864   5,045   4,578   4,507   8,357   2,197   5,909   4,732
# 3    1893   7,298   5,038   4,579   4,436   8,584   2,279   6,275   4,789
# 4    1894   7,411   5,283   4,579   4,601   8,286   2,215   6,405   4,841
# ..    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 125  2015  48,509  48,980  42,817  46,779  68,523  23,702  48,500  47,156
# 126  2016  48,887  49,463  43,230  46,715  68,946  23,790  49,183  48,309
# 127  2017  49,484  50,337  43,884  47,624  69,535  23,732  50,274  48,976
# 128  2018  49,654  51,304  44,334  47,909  70,923  24,329  50,759  49,899
# 129  2019  49,782  51,917  44,734  48,014  71,077  24,296  50,902  50,851
#
#         ESP  ...     JPN     MEX     NLD     NOR     NZL     PRT     SWE  \
# ...
